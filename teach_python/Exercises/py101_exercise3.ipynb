# %% [markdown]
# # Exercise 3
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
#
# 1. Use the preloaded data provided in this notebook and perform a wide-to-long transformation to the data. Follow the instructions stated in the link below:
#     - https://towardsdatascience.com/reshaping-a-pandas-dataframe-long-to-wide-and-vice-versa-517c7f0995ad
# 2. The end result should be a table with the following column structure:
#     - State, Measure, Month, Deaths
# 3. Submit the practice notebook (ipynb file) with your name in the filename provided below:
#     - \\\\mh.org\\Public\\CO\\CO - DSci Python Community\\Training\\Python_101_Summer2023\\Exercises

# %%
import pandas as pd

df = pd.read_csv('//clinisilonhh/ifs/PHI_Access/PHI-CO - DSci Nhan Tran/Python Curriculum Dev/Exercises/exercise4_dataset.csv')
df
# Out:
#              State                  Measure     Jan   Feb     Mar     Apr  \
# 0          Alabama  Sum of Influenza Deaths    47.0    39    33.0    10.0
# 1           Alaska  Sum of Influenza Deaths     0.0     0     0.0     0.0
# 2          Arizona  Sum of Influenza Deaths    53.0    54    39.0     NaN
# 3         Arkansas  Sum of Influenza Deaths    22.0    35    29.0     0.0
# 4       California  Sum of Influenza Deaths   307.0   307   189.0    31.0
# ..             ...                      ...     ...   ...     ...     ...
# 103       Virginia  Sum of Pneumonia Deaths  2935.0  1874  1236.0  1314.0
# 104     Washington  Sum of Pneumonia Deaths  2026.0  1433  1218.0  1163.0
# 105  West Virginia  Sum of Pneumonia Deaths  1248.0   881   607.0   545.0
# 106      Wisconsin  Sum of Pneumonia Deaths  1593.0   925   782.0   693.0
# 107        Wyoming  Sum of Pneumonia Deaths   175.0   138    95.0    75.0
#
#        May    Jun    Jul     Aug     Sep     Oct     Nov     Dec
# ...
